# %%
import json
import requests
from bs4 import BeautifulSoup

#아래에 코드 작성
page_no = "1"
num_of_rows = "100"
api_key = "AiMHAf%2BJJUylxroBA5LeiG%2FkXWULTMXWujS9xTtiD0TO23mWyND4uvsmnWlTJEZcr%2FWq5q6qzQBi0Ps2KrlD%2Fg%3D%3D"
url = "http://apis.data.go.kr/1741000/DisasterMsg3/getDisasterMsg1List?" + "pageNo=" + page_no + "&numOfRows=" + num_of_rows + "&type=json&serviceKey=" + api_key
response = requests.get(url, headers = header)
print(response.text)
# json_data = json.loads(response.text)
# msg_list = json_data["DisasterMsg"][1]["row"]

# for msg in msg_list:
#     print(msg["msg"])
# Out:
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP_ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>

# %%
import pandas as pd

#판다스를 이용하면 df로 즉시 변환 가능
df = pd.DataFrame(msg_list)
df
# Out:
#            create_date location_id location_name md101_sn  \
# 0  2021/06/20 18:34:57          47       경기도 이천시   109564
# 1  2021/06/20 18:14:50          46      경기도 의정부시   109563
# 2  2021/06/20 18:05:13          37       경기도 안성시   109562
# 3  2021/06/20 18:02:08          52       경기도 화성시   109561
# 4  2021/06/20 18:00:38          42       경기도 연천군   109559
# 5  2021/06/20 18:00:38          39       경기도 양주시   109560
# 6  2021/06/20 18:00:09          80      경상북도 김천시   109558
# 7  2021/06/20 18:00:08          32       경기도 부천시   109557
# 8  2021/06/20 18:00:06         113      대전광역시 전체   109556
# 9  2021/06/20 17:48:20          49       경기도 평택시   109555
#
#                                                  msg send_platform
# 0  [이천시청] 6월 20일 확진자5명 발생(타지역1,관내4),격리중확진1,확진자 접촉...           cbs
# 1  [의정부시청]6월20일 18시 기준, 일일확진자 9명 발생(1522~1530번) 홈...           cbs
# 2  [안성시청] 6.20.18시 기준 코로나19 확진자 1명(해외입국자 1)발생, 역학...           cbs
# ...
